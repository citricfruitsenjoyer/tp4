# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import glob
import pandas as pd
from scipy import signal as sn
plt.style.use('ggplot')



videos=['videos/20250528_170906-003.mp4','videos/20250528_173138.mp4','videos/20250528_173920.mp4','videos/20250528_175822.mp4',
        'videos/C1862-001.MP4','videos/C1871.MP4','videos/C1872.MP4','videos/C1873.MP4']
paths=[f"frames_video{i+1}/*" for i in range(len(videos))]

# %%
k=5
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))

img1 = cv.imread(path_list[0],cv.IMREAD_COLOR_RGB)
img2 = cv.imread(path_list[5050],cv.IMREAD_GRAYSCALE)

plt.imshow(img1)

# %%
delta=(img2-img1).astype(np.float64)
delta = delta[500:1750,1400:2500]
print(delta.shape)
softdelta=delta
# softdelta = sn.savgol_filter(delta,50,3)
# for i in range(3):
#     softdelta[:,:,i] = sn.savgol_filter(delta[:,:,i],50,3)

# softdelta=sn.savgol_filter(delta,50,3)
# arr_new = np.where(delta > 2, 0, delta)


print(np.max(softdelta))

threshold=90
delta[delta < threshold] = 0

plt.imshow(delta)
# Out:
# (1250, 1100)
# 255.0

# %%
k=0
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))

# size=np.size(img1)

for j,i in enumerate(path_list):
    img = cv.imread(i)
    img = 255-img

    img=img[315:1871,1523:3291,:]
 
    r[j] = np.sum(img[:,:,0])/np.size(img)

    g[j] = np.sum(img[:,:,1])/np.size(img)
    
    b[j] = np.sum(img[:,:,2])/np.size(img)


df_video1=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video1.to_csv('procesados/video1_rgb_surface.csv',index=False)

# %%
k=1
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))

for j,i in enumerate(path_list):
    img = cv.imread(i)
    img = 255-img
    slice1=img[456:501,1452:3269]
    slice2=img[756:793,1514:3257]
    slice3=img[1072:1095, 1445:3228]
 

    r_in = np.sum(slice1[:,:,0])/np.size(slice1)
    r_in += np.sum(slice2[:,:,0])/np.size(slice2)
    r_in += np.sum(slice3[:,:,0])/np.size(slice3)
    
    r[j] = r_in


    g_in = np.sum(slice1[:,:,1])/np.size(slice1)
    g_in += np.sum(slice2[:,:,1])/np.size(slice2)
    g_in += np.sum(slice3[:,:,1])/np.size(slice3)

    g[j] = g_in


    b_in = np.sum(slice1[:,:,2])/np.size(slice1)
    b_in += np.sum(slice2[:,:,2])/np.size(slice2)
    b_in += np.sum(slice3[:,:,2])/np.size(slice3)
    
    b[j] = b_in




df_video2=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video2.to_csv('procesados/video2_rgb_sliced.csv',index=False)

# %%
k=2
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))

for j,i in enumerate(path_list):
    img = cv.imread(i)
    img = 255-img
    slice1=img[462:491,1450:3266]
    slice2=img[753:800,1508:3259]
    slice3=img[1067:1095,1446:3226]


    r_in = np.sum(slice1[:,:,0])/np.size(slice1)
    r_in += np.sum(slice2[:,:,0])/np.size(slice2)
    r_in += np.sum(slice3[:,:,0])/np.size(slice3)
    
    r[j] = r_in


    g_in = np.sum(slice1[:,:,1])/np.size(slice1)
    g_in += np.sum(slice2[:,:,1])/np.size(slice2)
    g_in += np.sum(slice3[:,:,1])/np.size(slice3)

    g[j] = g_in


    b_in = np.sum(slice1[:,:,2])/np.size(slice1)
    b_in += np.sum(slice2[:,:,2])/np.size(slice2)
    b_in += np.sum(slice3[:,:,2])/np.size(slice3)
    
    b[j] = b_in




df_video3=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video3.to_csv('procesados/video3_rgb_sliced.csv',index=False)

# %%
k=3
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))

for j,i in enumerate(path_list):
    img = cv.imread(i)
    # img = 255-img
    slice1=img[431:465,1306:3125]
    slice2=img[711:773,1351:3117]
    slice3=img[1042:1066,1297:3083]


    r_in = np.sum(slice1[:,:,0])/np.size(slice1)
    r_in += np.sum(slice2[:,:,0])/np.size(slice2)
    r_in += np.sum(slice3[:,:,0])/np.size(slice3)
    
    r[j] = r_in


    g_in = np.sum(slice1[:,:,1])/np.size(slice1)
    g_in += np.sum(slice2[:,:,1])/np.size(slice2)
    g_in += np.sum(slice3[:,:,1])/np.size(slice3)

    g[j] = g_in


    b_in = np.sum(slice1[:,:,2])/np.size(slice1)
    b_in += np.sum(slice2[:,:,2])/np.size(slice2)
    b_in += np.sum(slice3[:,:,2])/np.size(slice3)
    
    b[j] = b_in




df_video4=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video4.to_csv('procesados/video4_rgb_sliced_alt.csv',index=False)

# %%
k=4

path_list=glob.glob(paths[k])
path = path_list[12000]
print(path)
img = cv.imread(path)
# img = 255-img 
r_in,g_in,b_in=0,0,0


slice1=img[523:615,2163:2263]
slice2=img[691:780,1829:1911]
slice3=img[881:1036,1547:1649]
slice4=img[954:1037,2119:2160]
slice5=img[1011:1133,1855:1937]
slice6=img[1261:1367,2171:2231]
slice7=img[1332:1484,1674:1731]


slices=[slice1,slice2,slice3,slice4,slice5,slice6,slice7]


for z in slices:
    plt.figure()
    plt.imshow(z)
# Out:
# frames_video5\frame012000.jpg

# %%
k=4

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))
r_in,g_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i)
    # img = 255-img 
    r_in,g_in,b_in=0,0,0


    slice1=img[523:615,2163:2263]
    slice2=img[691:780,1829:1911]
    slice3=img[881:1036,1547:1649]
    slice4=img[954:1037,2119:2160]
    slice5=img[1011:1133,1855:1937]
    slice6=img[1261:1367,2171:2231]
    slice7=img[1332:1484,1674:1731]


    slices=[slice1,slice2,slice3,slice4,slice5,slice6,slice7]

    for z in slices:
        r_in += np.sum(z[:,:,0])/np.size(z)
        g_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    r[j] = r_in
    g[j] = g_in
    b[j] = b_in





df_video5=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video5.to_csv('procesados/video5_rgb_sliced.csv',index=False)
# Out:
# 25.0

# %%
k=5

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))
r_in,g_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i)
    # img = 255-img 
    r_in,g_in,b_in=0,0,0


    slice1=img[873:1505,1723:2255]



    slices=[slice1]

    for z in slices:
        r_in += np.sum(z[:,:,0])/np.size(z)
        g_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    r[j] = r_in
    g[j] = g_in
    b[j] = b_in





df_video6=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video6.to_csv('procesados/video6_rgb_sliced.csv',index=False)
# Out:
# 25.0

# %%
plt.plot(df_video4[['r','g','b']])

# %%
k=6

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))
r_in,g_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i)
    # img = 255-img 
    r_in,g_in,b_in=0,0,0


    slice1=img[799:1485,2383:2860]



    slices=[slice1]

    for z in slices:
        r_in += np.sum(z[:,:,0])/np.size(z)
        g_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    r[j] = r_in
    g[j] = g_in
    b[j] = b_in





df_video7=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video7.to_csv('procesados/video7_rgb_sliced.csv',index=False)
plt.plot(df_video7[['r','g','b']])
# Out:
# 25.0

# %%
k=7

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

r,g,b=np.zeros(shape=(3,t.shape[0]))
r_in,g_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i)
    # img = 255-img 
    r_in,g_in,b_in=0,0,0


    slice1 = img[1070:1300, 2064:2217]
    slice2 = img[864:1596 , 2218:2418]
    slice3 = img[759:1644 , 2419:2610]
    slice4 = img[797:1644 , 2611:2746]
    slice5 = img[1046:1644, 2747:2930]


    slices=[slice1, slice2, slice3, slice4, slice5]

    for z in slices:
        r_in += np.sum(z[:,:,0])/np.size(z)
        g_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    r[j] = r_in
    g[j] = g_in
    b[j] = b_in





df_video8=pd.DataFrame({'t':t,'r':r,'g':g,'b':b})
df_video8.to_csv('procesados/video8_rgb_sliced.csv',index=False)
plt.plot(df_video8[['r','g','b']])
# Out:
# 25.0
# ...
