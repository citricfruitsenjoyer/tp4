# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
3*60*30
# Out:
# 5400

# %%
cam = cv.VideoCapture(0)   # 0 -> index of camera
s, img = cam.read()
frame_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(frame_rgb)

print(img.shape,type(s))
cam.release()
# Out:
# [ WARN:0@24.926] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# (720, 1280, 3) <class 'bool'>
