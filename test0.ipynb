# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
cam = cv.VideoCapture(0)   # 0 -> index of camera
s, img = cam.read()
frame_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(frame_rgb)

print(img.shape,type(s))
cam.release()
# Out:
# [ WARN:0@1551.840] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# (720, 1280, 3) <class 'bool'>

# %%
edges=cv.Canny(img,0,15)
img=cv.imread('DSC00094.JPG', cv.IMREAD_GRAYSCALE)

plt.figure(figsize=(16*1.5,9*1.5))
# plt.subplot(121),plt.imshow(img,cmap = 'gray')
# plt.title('Original Image'), plt.xticks([]), plt.yticks([])
# plt.subplot(122),plt.imshow(edges,cmap = 'gray')
# plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.imshow(edges)

# %%
import pandas as pd
df=pd.read_csv('tempgrabacion2.csv')
df.columns

df['Date/Time'] = df['Date/Time'].str.replace('A.M.', 'AM', regex=False)
df['Date/Time'] = df['Date/Time'].str.replace('P.M.', 'PM', regex=False)

# Convert to datetime
df['Date/Time'] = pd.to_datetime(df['Date/Time'], format='%d/%m/%Y %I:%M:%S %p')

# %%
df['999 [°C]']=df['999 [°C]'].to_numpy()
plt.figure(figsize=(16,9))
plt.plot(df['Date/Time'],df['999 [°C]'])
