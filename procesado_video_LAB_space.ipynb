# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import glob
import pandas as pd
from scipy import signal as sn
plt.style.use('ggplot')



videos=['videos/20250528_170906-003.mp4','videos/20250528_173138.mp4','videos/20250528_173920.mp4','videos/20250528_175822.mp4',
       'videos/C1862.MP4','videos/C1871.MP4','videos/C1872.MP4','videos/C1873.MP4','videos/C1883.MP4','videos/C1888.MP4','videos/C1889.MP4',
       'videos/C1896.MP4','videos/C1897.MP4','videos/C1899.MP4','videos/C1906.MP4','videos/C1907.MP4',
       'videos/C1910.MP4','videos/C1915.MP4','videos/C1917.MP4','videos/C1918.MP4'] #arranca en 12 
paths=[f"frames_video{i+1}/*" for i in range(len(videos))]
len(videos)
# Out:
# 20

# %%
k=7
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))

img = cv.imread(path_list[0], cv.IMREAD_COLOR_RGB)
plt.imshow(img)

# %%
# %%script false --no-raise-error
# k=0
# path_list=glob.glob(paths[k])
# cam = cv.VideoCapture(videos[k])
# fps = cam.get(cv.CAP_PROP_FPS)
# cam.release()
# dt=1/fps
# t=np.array([dt*x for x in range(len(path_list))])
#
# L,a,b=np.zeros(shape=(3,t.shape[0]))
#
# # size=np.size(img1)
#
# for j,i in enumerate(path_list):
#     img = cv.imread(i,cv.IMREAD_COLOR_RGB)
#     img = cv.cvtColor(img, cv.COLOR_RGB2LAB)
#
#     img=img[315:1871,1523:3291,:]
#
#     L_in,a_in,b_in=0,0,0
#     slices=[img]
#
#     for z in slices:
#         L_in += np.sum(z[:,:,0])/np.size(z)
#         a_in += np.sum(z[:,:,1])/np.size(z)
#         b_in += np.sum(z[:,:,2])/np.size(z)
#
#     L[j] = L_in/len(slices)
#     a[j] = a_in/len(slices)
#     b[j] = b_in/len(slices)
#
# df_video1=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
# df_video1.to_csv('procesados/video1_Lab_surface.csv',index=False)

# %%
# %%script false --no-raise-error
# k=1
# path_list=glob.glob(paths[k])
# cam = cv.VideoCapture(videos[k])
# fps = cam.get(cv.CAP_PROP_FPS)
# cam.release()
# dt=1/fps
# t=np.array([dt*x for x in range(len(path_list))])
#
# L,a,b=np.zeros(shape=(3,t.shape[0]))
#
# for j,i in enumerate(path_list):
#     img = cv.imread(i,cv.IMREAD_COLOR_RGB)
#     img = cv.cvtColor(img, cv.COLOR_RGB2LAB)
#     slice1=img[456:501,1452:3269]
#     slice2=img[756:793,1514:3257]
#     slice3=img[1072:1095, 1445:3228]
#
#
#     L_in,a_in,b_in=0,0,0
#     slices=[slice1,slice2,slice3]
#
#     for z in slices:
#         L_in += np.sum(z[:,:,0])/np.size(z)
#         a_in += np.sum(z[:,:,1])/np.size(z)
#         b_in += np.sum(z[:,:,2])/np.size(z)
#
#     L[j] = L_in/len(slices)
#     a[j] = a_in/len(slices)
#     b[j] = b_in/len(slices)
#
#
#
#
# df_video2=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
# df_video2.to_csv('procesados/video2_Lab_sliced.csv',index=False)

# %%
# %%script false --no-raise-error
# k=2
# path_list=glob.glob(paths[k])
# cam = cv.VideoCapture(videos[k])
# fps = cam.get(cv.CAP_PROP_FPS)
# cam.release()
# dt=1/fps
# t=np.array([dt*x for x in range(len(path_list))])
#
# L,a,b=np.zeros(shape=(3,t.shape[0]))
#
# for j,i in enumerate(path_list):
#     img = cv.imread(i,cv.IMREAD_COLOR_RGB)
#     img = cv.cvtColor(img, cv.COLOR_RGB2LAB)
#     slice1=img[462:491,1450:3266]
#     slice2=img[753:800,1508:3259]
#     slice3=img[1067:1095,1446:3226]
#
#     L_in,a_in,b_in=0,0,0
#     slices=[slice1,slice2,slice3]
#
#     for z in slices:
#         L_in += np.sum(z[:,:,0])/np.size(z)
#         a_in += np.sum(z[:,:,1])/np.size(z)
#         b_in += np.sum(z[:,:,2])/np.size(z)
#
#     L[j] = L_in/len(slices)
#     a[j] = a_in/len(slices)
#     b[j] = b_in/len(slices)
#
#
#
#
# df_video3=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
# df_video3.to_csv('procesados/video3_Lab_sliced.csv',index=False)

# %%
k=3
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB)
    slice1=img[431:465,1306:3125]
    slice2=img[711:773,1351:3117]
    slice3=img[1042:1066,1297:3083]

    L_in,a_in,b_in=0,0,0
    slices=[slice1,slice2,slice3]

    for z in slices:
        L_in += np.sum(z[:,:,0])/np.size(z)
        a_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    L[j] = L_in/len(slices)
    a[j] = a_in/len(slices)
    b[j] = b_in/len(slices)




df_video4=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video4.to_csv('procesados/video4_Lab_sliced_alt.csv',index=False)

# %%
k=4

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    L_in,a_in,b_in=0,0,0


    slice1=img[523:615,2163:2263]
    slice2=img[691:780,1829:1911]
    slice3=img[881:1036,1547:1649]
    slice4=img[954:1037,2119:2160]
    slice5=img[1011:1133,1855:1937]
    slice6=img[1261:1367,2171:2231]
    slice7=img[1332:1484,1674:1731]


    slices=[slice1,slice2,slice3,slice4,slice5,slice6,slice7]

    for z in slices:
        L_in += np.sum(z[:,:,0])/np.size(z)
        a_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    L[j] = L_in/len(slices)
    a[j] = a_in/len(slices)
    b[j] = b_in/len(slices)





df_video5=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video5.to_csv('procesados/video5_Lab_sliced.csv',index=False)

# %%
# %%script false --no-raise-error
#
# k=5
#
# path_list=glob.glob(paths[k])
# cam = cv.VideoCapture(videos[k])
# fps = cam.get(cv.CAP_PROP_FPS)
# print(fps)
# cam.release()
# dt=1/fps
# t=np.array([dt*x for x in range(len(path_list))])
#
# L,a,b=np.zeros(shape=(3,t.shape[0]))
# L_in,a_in,b_in=0,0,0
#
#
# for j,i in enumerate(path_list):
#     img = cv.imread(i,cv.IMREAD_COLOR_RGB)
#     img = cv.cvtColor(img, cv.COLOR_RGB2LAB)
#     L_in,a_in,b_in=0,0,0
#
#
#     slice1=img[873:1505,1723:2255]
#
#
#
#     slices=[slice1]
#
#     for z in slices:
#         L_in += np.sum(z[:,:,0])/np.size(z)
#         a_in += np.sum(z[:,:,1])/np.size(z)
#         b_in += np.sum(z[:,:,2])/np.size(z)
#
#     L[j] = L_in/len(slices)
#     a[j] = a_in/len(slices)
#     b[j] = b_in/len(slices)
#
#
#
#
#
# df_video6=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
# df_video6.to_csv('procesados/video6_Lab_sliced.csv',index=False)

# %%
k=6

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    L_in,a_in,b_in=0,0,0


    slice1=img[799:1485,2383:2860]

    slices=[slice1]

    for z in slices:
        L_in += np.sum(z[:,:,0])/np.size(z)
        a_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    L[j] = L_in/len(slices)
    a[j] = a_in/len(slices)
    b[j] = b_in/len(slices)





df_video7=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video7.to_csv('procesados/video7_Lab_sliced.csv',index=False)
plt.plot(df_video7[['L','a','b']])

# %%
k=7

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    L_in,a_in,b_in=0,0,0


    slice1 = img[1070:1300, 2064:2217]
    slice2 = img[864:1596 , 2218:2418]
    slice3 = img[759:1644 , 2419:2610]
    slice4 = img[797:1644 , 2611:2746]
    slice5 = img[1046:1644, 2747:2930]


    slices=[slice1, slice2, slice3, slice4, slice5]

    for z in slices:
        L_in += np.sum(z[:,:,0])/np.size(z)
        a_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    L[j] = L_in/len(slices)
    a[j] = a_in/len(slices)
    b[j] = b_in/len(slices)



df_video8=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video8.to_csv('procesados/video8_Lab_sliced.csv',index=False)
plt.plot(df_video8[['L']])

# %%
k=8
#frame 355 arranca

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0


for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    L_in,a_in,b_in=0,0,0


    slice1 = img[575:1206 , 1758:1955]
    slice2 = img[420:1284 , 1956:2126]
    slice3 = img[498:1316 , 2127:2287]
    slice4 = img[594:1357 , 2288:2445]
    slice5 = img[774:1255 , 2246:2561]


    slices=[slice1, slice2, slice3, slice4, slice5]

    for z in slices:
        L_in += np.sum(z[:,:,0])/np.size(z)
        a_in += np.sum(z[:,:,1])/np.size(z)
        b_in += np.sum(z[:,:,2])/np.size(z)
    
    L[j] = L_in/len(slices)
    a[j] = a_in/len(slices)
    b[j] = b_in/len(slices)



df_video9=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video9.to_csv('procesados/video9_Lab_sliced.csv',index=False)
plt.plot(df_video9[['L']])

# %%
k=9

path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0
#152 arranca

p1 = path_list[152]
p2 = path_list[5838]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[415:1423,1845:2848]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[415:1423,1845:2848]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 200, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[415:1423,1845:2848]
    
    L_in,a_in,b_in=0,0,0
    
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in


df_video10=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video10.to_csv('procesados/video10_Lab_sliced.csv',index=False)
plt.plot(df_video10[['L']])

# %%
k=10
#047 arranca a medir temp
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[876]
p2 = path_list[2991]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[738:1356 , 1838:2846]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[738:1356 , 1838:2846]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[738:1356 , 1838:2846]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video11=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video11.to_csv('procesados/video11_Lab_sliced.csv',index=False)
plt.plot(df_video11[['L']])

# %%
k=11
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[4949]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1077:1611 , 1463:2324]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1077:1611 , 1463:2324]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1077:1611 , 1463:2324]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video12=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video12.to_csv('procesados/video12_Lab_sliced.csv',index=False)
plt.plot(df_video12[['L']])
# Out:
# 25.0

# %%
k=12
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[2025]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1134:1768 , 1404:2469]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1134:1768 , 1404:2469]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1134:1768 , 1404:2469]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in


df_video13=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video13.to_csv('procesados/video13_Lab_deriva.csv',index=False)
plt.plot(df_video13[['L']])
# Out:
# 25.0

# %%
k=13
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[7403]
p2 = path_list[2100]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1123:1771 , 1406:2472]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1123:1771 , 1406:2472]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1123:1771 , 1406:2472]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video14=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video14.to_csv('procesados/video14_Lab_sliced.csv',index=False)
plt.plot(df_video14[['L']])
# Out:
# 25.0

# %%
k=14
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[1950]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1130:1730 , 1485:2366]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1130:1730 , 1485:2366]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1130:1730 , 1485:2366]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video15=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video15.to_csv('procesados/video15_Lab_sliced.csv',index=False)
plt.plot(df_video15[['L']])
# Out:
# 25.0

# %%
k=15
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[2150]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1130:1730 , 1485:2366]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1130:1730 , 1485:2366]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1130:1730 , 1485:2366]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video16=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video16.to_csv('procesados/video16_Lab_sliced.csv',index=False)
plt.plot(df_video16[['L']])
# Out:
# 25.0

# %%
k=16
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[7557]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1214:1771 , 1332:2232]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1214:1771 , 1332:2232]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1214:1771 , 1332:2232]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video17=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video17.to_csv('procesados/video17_Lab_sliced.csv',index=False)
plt.plot(df_video17[['L']])
# Out:
# 25.0

# %%
k=17
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[0]
p2 = path_list[5450]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1171:1788 , 1248:2081]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1171:1788 , 1248:2081]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1171:1788 , 1248:2081]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video18=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video18.to_csv('procesados/video18_Lab_sliced.csv',index=False)
plt.plot(df_video18[['L']])
# Out:
# 25.0

# %%
k=18
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[19619]
p2 = path_list[14525]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1195:1804 , 1296:2097]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1195:1804 , 1296:2097]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1195:1804 , 1296:2097]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video19=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video19.to_csv('procesados/video19_Lab_sliced.csv',index=False)
plt.plot(df_video19[['L']])
# Out:
# 25.0

# %%
k=19
path_list=glob.glob(paths[k])
cam = cv.VideoCapture(videos[k])
fps = cam.get(cv.CAP_PROP_FPS)
print(fps)
cam.release()
dt=1/fps
t=np.array([dt*x for x in range(len(path_list))])

L,a,b=np.zeros(shape=(3,t.shape[0]))
L_in,a_in,b_in=0,0,0

p1 = path_list[7750]
p2 = path_list[21750]

img1 = cv.imread(p1,cv.IMREAD_GRAYSCALE)
img1 = img1[1193:1819 , 1274:2100]

img2= cv.imread(p2,cv.IMREAD_GRAYSCALE)
img2 = img2[1193:1819 , 1274:2100]

delta = (img1 - img2).astype(np.float64)

arr_new = np.where(delta > 235, 0, delta)       #si soy completamente sincero varias de estas ultimas 
arr_new2 = np.where(arr_new > 30, 255, arr_new) #lineas fueron random bullshit go, ni tengo idea de 
arr_new2[arr_new2 < 30] = 0                     #si esto hace algo o no
mask = (arr_new2 == 255)
size = np.sum(mask)
size

for j,i in enumerate(path_list):
    img = cv.imread(i,cv.IMREAD_COLOR_RGB)
    img = cv.cvtColor(img, cv.COLOR_RGB2LAB) 
    img = img[1193:1819 , 1274:2100]
    
    L_in,a_in,b_in=0,0,0
    output = np.zeros_like(img)         # Todo negro
    output[mask] = img[mask]            # Copiar solo donde mask es True

    L_in += np.sum(img[:,:,0])/size
    a_in += np.sum(img[:,:,1])/size
    b_in += np.sum(img[:,:,2])/size
    
    L[j] = L_in
    a[j] = a_in
    b[j] = b_in

df_video20=pd.DataFrame({'t':t,'L':L,'a':a,'b':b})
df_video20.to_csv('procesados/video20_Lab_sliced.csv',index=False)
plt.plot(df_video20[['L']])
# Out:
# 25.0
